# %%
import pandas as pd
import seaborn as sns
from pytrends.request import TrendReq

pytrends = TrendReq()

# %%
kw_list=['ชาบู']

pytrends.build_payload(kw_list, cat=0, timeframe='today 1-m' , geo='TH', gprop='')

# %%
df = pytrends.interest_over_time()
df = df.reset_index()

# %%
ax = sns.lineplot(x="date", y="ชาบู", data=df)
# Out:
# /root/.local/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3594 (\N{THAI CHARACTER CHO CHANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.local/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.local/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3610 (\N{THAI CHARACTER BO BAIMAI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.local/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3641 (\N{THAI CHARACTER SARA UU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
